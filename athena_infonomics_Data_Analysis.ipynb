# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## DATA SET 1:

# %%
#importing datset Daily_Power_Gen_Source_march_23.csv

# %%
df1=pd.read_csv("Daily_Power_Gen_Source_march_23.csv")

# %%
df1.head()
# Out:
#          source     NR     WR     SR     ER   NER  All India        date
# 0         Hydro  139.0   43.0   72.0   30.0   7.0        292  2013-03-31
# 1         Total  675.0  820.0  697.0  306.0  28.0       2526  2013-03-31
# 2  Wind Gen(MU)    2.0   19.0   13.0    0.0   0.0         34  2013-03-31
# 3         Hydro  137.0   43.0   83.0   32.0   5.0        300  2013-04-01
# 4         Total  683.0  841.0  706.0  316.0  29.0       2575  2013-04-01

# %%
#to see numbers of rows and columns 
print(df1.shape)
# Out:
# (18251, 8)

# %%
#removing all rows having 'Total' in 'source' column
df1_source= df1.drop(df1[df1['source'] == 'Total'].index)

# %%
df1_source.head()
# Out:
#          source     NR    WR    SR    ER  NER  All India        date
# 0         Hydro  139.0  43.0  72.0  30.0  7.0        292  2013-03-31
# 2  Wind Gen(MU)    2.0  19.0  13.0   0.0  0.0         34  2013-03-31
# 3         Hydro  137.0  43.0  83.0  32.0  5.0        300  2013-04-01
# 5  Wind Gen(MU)    7.0  21.0  19.0   0.0  0.0         48  2013-04-01
# 6  Wind Gen(MU)    8.0  25.0  15.0   0.0  0.0         48  2013-04-02

# %%
print(df1_source.shape)
# Out:
# (14822, 8)

# %%
df1_source.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14822 entries, 0 to 18249
# Data columns (total 8 columns):
# source       14822 non-null object
# NR           14822 non-null float64
# WR           14822 non-null float64
# SR           14822 non-null float64
# ER           14822 non-null float64
# NER          14822 non-null float64
# All India    14822 non-null int64
# date         14822 non-null object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 1.0+ MB

# %%
df1_source.isnull().sum()
# Out:
# source       0
# NR           0
# WR           0
# SR           0
# ER           0
# NER          0
# All India    0
# date         0
# dtype: int64

# %%
#from o/p it is clear that there are no null values in df1

# %%
#checking for duplicate values

# %%
df1_source.duplicated().any()
# Out:
# False

# %%
#from above results it is clear that df1 and df2 do not contains any duplicates value

# %%
#extracting day , month and year from date object from df1:

# %%
#for df1
df1_source['date'] = pd.to_datetime(df1['date'])

df1_source['day'] = df1_source['date'].dt.day
df1_source['month'] = df1_source['date'].dt.month
df1_source['year'] = df1_source['date'].dt.year

# %%
df1_source.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14822 entries, 0 to 18249
# Data columns (total 11 columns):
# source       14822 non-null object
# NR           14822 non-null float64
# WR           14822 non-null float64
# SR           14822 non-null float64
# ER           14822 non-null float64
# NER          14822 non-null float64
# All India    14822 non-null int64
# date         14822 non-null datetime64[ns]
# day          14822 non-null int64
# month        14822 non-null int64
# year         14822 non-null int64
# dtypes: datetime64[ns](1), float64(5), int64(4), object(1)
# memory usage: 1.4+ MB

# %%
df1_source.head()
# Out:
#          source     NR    WR    SR    ER  NER  All India       date  day  \
# 0         Hydro  139.0  43.0  72.0  30.0  7.0        292 2013-03-31   31
# 2  Wind Gen(MU)    2.0  19.0  13.0   0.0  0.0         34 2013-03-31   31
# 3         Hydro  137.0  43.0  83.0  32.0  5.0        300 2013-04-01    1
# 5  Wind Gen(MU)    7.0  21.0  19.0   0.0  0.0         48 2013-04-01    1
# 6  Wind Gen(MU)    8.0  25.0  15.0   0.0  0.0         48 2013-04-02    2
#
#    month  year
# 0      3  2013
# 2      3  2013
# 3      4  2013
# 5      4  2013
# 6      4  2013

# %% [markdown]
# ## DATA SET 2:

# %%
#IMPORTING DATASET 2

# %%
df2=pd.read_csv("Daily_Power_Gen_States_march_23.csv")

# %%
df2.head()
# Out:
#   Region       States  Max.Demand Met during the day(MW)  \
# 0    NER      Mizoram                                 77
# 1     WR           DD                                214
# 2     WR          Goa                                383
# 3     WR  Maharashtra                              14837
# 4     WR           MP                               5740
#
#    Shortage during maximum Demand(MW)  Energy Met (MU)        date
# 0                                 1.0              1.2  2015-01-01
# 1                                 0.0              4.8  2015-01-01
# 2                                 0.0              7.3  2015-01-01
# 3                                57.0            315.0  2015-01-01
# 4                                 0.0            109.8  2015-01-01

# %%
print(df2.shape)
# Out:
# (126699, 6)

# %%
df2.head()
# Out:
#   Region       States  Max.Demand Met during the day(MW)  \
# 0    NER      Mizoram                                 77
# 1     WR           DD                                214
# 2     WR          Goa                                383
# 3     WR  Maharashtra                              14837
# 4     WR           MP                               5740
#
#    Shortage during maximum Demand(MW)  Energy Met (MU)        date
# 0                                 1.0              1.2  2015-01-01
# 1                                 0.0              4.8  2015-01-01
# 2                                 0.0              7.3  2015-01-01
# 3                                57.0            315.0  2015-01-01
# 4                                 0.0            109.8  2015-01-01

# %%
print(df2.shape)
# Out:
# (126699, 6)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126699 entries, 0 to 126698
# Data columns (total 6 columns):
# Region                                126699 non-null object
# States                                126699 non-null object
# Max.Demand Met during the day(MW)     126699 non-null int64
# Shortage during maximum Demand(MW)    126680 non-null float64
# Energy Met (MU)                       126698 non-null float64
# date                                  126699 non-null object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 5.8+ MB

# %%
df2.isnull().sum()
# Out:
# Region                                 0
# States                                 0
# Max.Demand Met during the day(MW)      0
# Shortage during maximum Demand(MW)    19
# Energy Met (MU)                        1
# date                                   0
# dtype: int64

# %%
#from o/p it is clear that there are 19 null values in column  Shortage during maximum Demand(MW) of df2

# %%
df2['Shortage during maximum Demand(MW)'] = df2['Shortage during maximum Demand(MW)'].fillna(df2['Shortage during maximum Demand(MW)'].mean())

# %%
df2['Energy Met (MU)'] = df2['Energy Met (MU)'].fillna(0)

# %%
df2.isnull().sum()
# Out:
# Region                                0
# States                                0
# Max.Demand Met during the day(MW)     0
# Shortage during maximum Demand(MW)    0
# Energy Met (MU)                       0
# date                                  0
# dtype: int64

# %%
#we have replace null values with mean "Shortage during maximum Demand(MW)" and 0 for "Energy Met (MU)" resp.

# %%
df2.duplicated().any()
# Out:
# False

# %%
#from above results it is clear that  df2 do not contains any duplicates value

# %%
#extracting day , month and year from date object from  df2

# %%
#for df2
df2['date'] = pd.to_datetime(df2['date'])

df2['day'] = df2['date'].dt.day
df2['month'] = df2['date'].dt.month
df2['year'] = df2['date'].dt.year

# %%
df2.head()
# Out:
#   Region       States  Max.Demand Met during the day(MW)  \
# 0    NER      Mizoram                                 77
# 1     WR           DD                                214
# 2     WR          Goa                                383
# 3     WR  Maharashtra                              14837
# 4     WR           MP                               5740
#
#    Shortage during maximum Demand(MW)  Energy Met (MU)       date  day  month  \
# 0                                 1.0              1.2 2015-01-01    1      1
# 1                                 0.0              4.8 2015-01-01    1      1
# 2                                 0.0              7.3 2015-01-01    1      1
# 3                                57.0            315.0 2015-01-01    1      1
# 4                                 0.0            109.8 2015-01-01    1      1
#
#    year
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126699 entries, 0 to 126698
# Data columns (total 9 columns):
# Region                                126699 non-null object
# States                                126699 non-null object
# Max.Demand Met during the day(MW)     126699 non-null int64
# Shortage during maximum Demand(MW)    126699 non-null float64
# Energy Met (MU)                       126699 non-null float64
# date                                  126699 non-null datetime64[ns]
# day                                   126699 non-null int64
# month                                 126699 non-null int64
# year                                  126699 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(2)
# memory usage: 8.7+ MB

# %%
#df2['Energy Met (MU)']=df2['Energy Met (MU)']*1000
df2.rename(columns={'Energy Met (MU)': 'Energy Met (MW)'}, inplace=True)
df2['Energy Met (MW)']=df2['Energy Met (MW)']*1000

# %%
df2.head()
# Out:
#   Region       States  Max.Demand Met during the day(MW)  \
# 0    NER      Mizoram                                 77
# 1     WR           DD                                214
# 2     WR          Goa                                383
# 3     WR  Maharashtra                              14837
# 4     WR           MP                               5740
#
#    Shortage during maximum Demand(MW)  Energy Met (MW)       date  day  month  \
# 0                                 1.0           1200.0 2015-01-01    1      1
# 1                                 0.0           4800.0 2015-01-01    1      1
# 2                                 0.0           7300.0 2015-01-01    1      1
# 3                                57.0         315000.0 2015-01-01    1      1
# 4                                 0.0         109800.0 2015-01-01    1      1
#
#    year
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # DATASET 1:

# %%
df1_source.describe()
# Out:
#                  NR            WR            SR            ER           NER  \
# count  14822.000000  14822.000000  14822.000000  14822.000000  14822.000000
# mean     144.294559    192.747309    129.275448     77.964625      8.239123
# std      188.317055    385.111533    160.078391    161.101873     10.276652
# min       -2.940000      0.000000      2.000000      0.000000      0.000000
# 25%       23.000000     21.000000     33.000000      0.000000      0.000000
# 50%       43.000000     38.000000     63.000000      1.000000      2.000000
# 75%      176.000000     82.000000    147.000000     51.000000     15.000000
# max      829.000000   1565.000000    745.000000    743.000000     52.000000
#
#           All India           day         month          year
# count  14822.000000  14822.000000  14822.000000  14822.000000
# mean     552.463838     15.756780      6.518149   2018.888477
# std      867.984287      8.781387      3.519928      2.613752
# min       13.000000      1.000000      1.000000   2013.000000
# 25%       94.000000      8.000000      3.000000   2017.000000
# 50%      208.000000     16.000000      7.000000   2019.000000
# 75%      453.000000     23.000000     10.000000   2021.000000
# max     3695.000000     31.000000     12.000000   2023.000000

# %%
df1_source1=df1_source.copy()
print(df1_source1.columns)
# Out:
# Index(['source', 'NR', 'WR', 'SR', 'ER', 'NER', 'All India', 'date', 'day',
#        'month', 'year'],
#       dtype='object')

# %%
# Assuming df1_source1 is your DataFrame containing the data
plt.figure(figsize=(10, 6))
for source, data in df1_source1.groupby('source'):
    plt.plot(data['date'], data['All India'], label=source)
plt.title('Power Generation by Source over Time')
plt.xlabel('Date')
plt.ylabel('Power Generation')
plt.legend()
plt.show()

# %%
df1_source1.head()
# Out:
#          source     NR    WR    SR    ER  NER  All India       date  day  \
# 0         Hydro  139.0  43.0  72.0  30.0  7.0        292 2013-03-31   31
# 2  Wind Gen(MU)    2.0  19.0  13.0   0.0  0.0         34 2013-03-31   31
# 3         Hydro  137.0  43.0  83.0  32.0  5.0        300 2013-04-01    1
# 5  Wind Gen(MU)    7.0  21.0  19.0   0.0  0.0         48 2013-04-01    1
# 6  Wind Gen(MU)    8.0  25.0  15.0   0.0  0.0         48 2013-04-02    2
#
#    month  year
# 0      3  2013
# 2      3  2013
# 3      4  2013
# 5      4  2013
# 6      4  2013

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df1_source1, y='source', x='All India')
plt.title('Power Generation by Source')
plt.ylabel('Source')
plt.xlabel('Power Generation')
plt.show()

# %%
# Time series analysis
df1_source1['date'] = pd.to_datetime(df1_source1['date'])
df1_source1.set_index('date', inplace=True)
hydro_generation = df1_source1[df1_source1['source'] == 'Hydro']['All India']
plt.figure(figsize=(10, 6))
hydro_generation.plot()
plt.title('Hydro Power Generation over Time')
plt.xlabel('Date')
plt.ylabel('Power Generation')
plt.show()

# %% [markdown]
# ## Comparison Between Renewable and Non-Renewable Sources of Power Generation

# %%
import warnings

# Ignore warning messages
warnings.filterwarnings("ignore")

#df1=pd.read_csv("Daily_Power_Gen_Source_march_23.csv")


#df1_source= df1.drop(df1[df1['source'] == 'Total'].index)

res_data = df1_source[df1_source['source'].str.startswith('RES')]
res_data['date'] = res_data['date'].astype(str)
res_data = res_data.groupby(res_data['date'].str.split('-').str[0])['All India'].sum().reset_index()

gas_data = df1_source[df1_source['source'].str.startswith('Gas')]
gas_data['date'] = gas_data['date'].astype(str)
gas_data = gas_data.groupby(gas_data['date'].str.split('-').str[0])['All India'].sum().reset_index()

combined_data = res_data.merge(gas_data, on='date')
combined_data.columns = ['Year', 'Renewable Energy', 'Fossil Fuels']

plt.figure(figsize=(10, 6))
plt.plot(combined_data['Year'], combined_data['Renewable Energy'], label='Renewable Energy', color="green")
plt.plot(combined_data['Year'], combined_data['Fossil Fuels'], label='Fossil Fuels', color="brown")

plt.xlabel('Year')
plt.ylabel('Power Generation')
plt.title('Power Generation Comparison')
plt.legend()

# Setting the background color
fig = plt.gcf()
fig.set_facecolor('lightgray') 

plt.show()

# %%
# Plot the pie chart
plt.pie(df1_source_grouped, labels=df1_source_grouped.index, autopct='%1.1f%%')
plt.title('Total Energy production by Source (2013-2023)')
plt.show()

# %% [markdown]
# ## DATASET 2:

# %%
df2.head()
# Out:
#   Region       States  Max.Demand Met during the day(MW)  \
# 0    NER      Mizoram                                 77
# 1     WR           DD                                214
# 2     WR          Goa                                383
# 3     WR  Maharashtra                              14837
# 4     WR           MP                               5740
#
#    Shortage during maximum Demand(MW)  Energy Met (MW)       date  day  month  \
# 0                                 1.0           1200.0 2015-01-01    1      1
# 1                                 0.0           4800.0 2015-01-01    1      1
# 2                                 0.0           7300.0 2015-01-01    1      1
# 3                                57.0         315000.0 2015-01-01    1      1
# 4                                 0.0         109800.0 2015-01-01    1      1
#
#    year
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015

# %% [markdown]
# # Region wise representation of Nation wise Power Distribution In India #

# %%
df_grouped = df2.groupby('Region')['Max.Demand Met during the day(MW)'].max()
print(df_grouped)
# Out:
# Region
# ER       9989
# NER      2376
# NR      33137
# SR      18048
# WR     111539
# Name: Max.Demand Met during the day(MW), dtype: int64

# %%
df_grouped = df2.groupby('Region')['Max.Demand Met during the day(MW)'].sum()

# Plot the pie chart
plt.pie(df_grouped, labels=df_grouped.index, autopct='%1.1f%%')
plt.title('Max.Demand Met during the day(MW) by Region')
plt.show()

# %%
df_grouped = df2.groupby('Region')['Shortage during maximum Demand(MW)'].sum()

# Plot the pie chart
plt.pie(df_grouped, labels=df_grouped.index, autopct='%1.1f%%')
plt.title('Shortage during maximum Demand(MW) by Region')
plt.show()

# %% [markdown]
# # State wise representation of Nation wise Power Distribution #

# %%
print(df2['year'].unique())
# Out:
# [2015 2016 2018 2019 2020 2021 2022 2023 2014 2017 2013]

# %%
print(df2['year'].nunique())
# Out:
# 11

# %%
print(df2['States'].nunique())
# Out:
# 45

# %%
print(df2['States'].unique())
# Out:
# ['Mizoram' 'DD' 'Goa' 'Maharashtra' 'MP' 'Gujarat' 'Chhattisgarh' 'DNH'
#  'Chandigarh' 'HP' 'Uttarakhand' 'UP' 'Delhi' 'Rajasthan' 'Haryana' 'J&K'
#  'Punjab' 'Essar steel' 'Andhra Pradesh' 'Meghalaya' 'Manipur' 'Assam'
#  'Arunachal Pradesh' 'Sikkim' 'West Bengal' 'Odisha' 'Jharkhand' 'DVC'
#  'Bihar' 'Pondy' 'Tamil Nadu' 'Kerala' 'Karnataka' 'Telangana' 'Nagaland'
#  'Tripura' 'J&K(UT) and Ladakh(UT)' 'J&K(UT) & Ladakh(UT)' 'AMNSIL'
#  'Puducherry' 'BALCO' 'DNHDDPDCL' 'J&K(UT) & \nLadakh(UT)' 'J&K(UT) &'
#  'Railways_NR ISTS']

# %%
state_count = df2.groupby('States')['Max.Demand Met during the day(MW)'].count()

# %%
state_max_demand = df2.groupby('States')['Max.Demand Met during the day(MW)'].sum()

state_max_demand = state_max_demand.sort_values(ascending=False)

top_states = state_max_demand.head(10)

plt.bar(top_states.index, top_states.values)
plt.xlabel('States')
plt.ylabel('Max.Demand Met during the year(MW)')
plt.title('Top States with Highest Max.Demand Met during the (MW)')
plt.xticks(rotation=90)
plt.show()

# %%
state_max_demand = df2.groupby('States')['Shortage during maximum Demand(MW)'].sum()

state_max_demand = state_max_demand.sort_values(ascending=False)

top_states = state_max_demand.head(10)

plt.bar(top_states.index, top_states.values)
plt.xlabel('States')
plt.ylabel('Shortage during maximum Demand(MW)')
plt.title('Top States with Shortage during maximum Demand(MW) during year')
plt.xticks(rotation=90)
plt.show()

# %%
df1
# Out:
#                                     source      NR      WR      SR     ER  \
# 8          NR            Chandigarh                                224
# 9          NR                    HP                               1367
# 10         NR           Uttarakhand                               1768
# 11         NR                    UP                               9998
# 12         NR                 Delhi                               4009
# 13         NR             Rajasthan                               9810
# 14         NR               Haryana                               6025
# 15         NR                   J&K                               1959
# 16         NR                Punjab                               5045
# 17         WR           Essar steel                                258
# 18         SR        Andhra Pradesh                               5963
# 19        NER             Meghalaya                                311
# 20        NER               Manipur                                136
# 21        NER                 Assam                               1210
# 22        NER     Arunachal Pradesh                                103
# 23         ER                Sikkim                                 89
# 24         ER           West Bengal                               5888
# 25         ER                Odisha                               3011
# 26         ER             Jharkhand                               1012
# 27         ER                   DVC                               2243
# 28         ER                 Bihar                               2679
# 29         SR                 Pondy                                278
# ...       ...                   ...                                ...
# 126669     NR            Chandigarh                                247
# 126670     WR             DNHDDPDCL                               1161
# 126671     NR  J&K(UT) & Ladakh(UT)                               2826
# 126672     NR           Uttarakhand                               2203
# 126673     NR                    UP                              18878
# 126674     NR                 Delhi                               4455
# 126675     NR             Rajasthan                              16398
# 126676     NR               Haryana                               7223
# 126677     NR                Punjab                               7734
# 126678     NR                    HP                               1967
# 126679     WR                AMNSIL                                783
# 126680     WR                 BALCO                                519
# 126681     SR        Andhra Pradesh                              10268
# 126682    NER               Mizoram                                136
# 126683    NER             Meghalaya                                396
# 126684    NER               Manipur                                236
# 126685    NER                 Assam                               1508
# 126686     ER                Sikkim                                112
# 126687     ER           West Bengal                               6691
# 126688     ER                Odisha                               4753
# 126689     ER             Jharkhand                               1522
# 126690     ER                   DVC                               3517
# 126691     ER                 Bihar                               5089
# 126692     SR            Puducherry                                385
# 126693     SR            Tamil Nadu                              14738
# 126694     SR                Kerala                               3844
# 126695     SR             Karnataka                              13135
# 126696     SR             Telangana                              13723
# 126697    NER               Tripura                                226
# 126698    NER     Arunachal Pradesh                                141
#
#         Shortage during maximum Demand(MW)  Energy Met (MW)       date  day  \
# 0                                      1.0           1200.0 2015-01-01    1
# 1                                      0.0           4800.0 2015-01-01    1
# 2                                      0.0           7300.0 2015-01-01    1
# 3                                     57.0         315000.0 2015-01-01    1
# 4                                      0.0         109800.0 2015-01-01    1
# 5                                      0.0         246400.0 2015-01-01    1
# 6                                     18.0          64600.0 2015-01-01    1
# 7                                      0.0          14000.0 2015-01-01    1
# 8                                      0.0           3800.0 2015-01-01    1
# 9                                      0.0          25100.0 2015-01-01    1
# 10                                     0.0          33900.0 2015-01-01    1
# 11                                  3645.0         244000.0 2015-01-01    1
# 12                                     0.0          67600.0 2015-01-01    1
# 13                                     0.0         204900.0 2015-01-01    1
# 14                                     0.0         116800.0 2015-01-01    1
# 15                                   346.0          37300.0 2015-01-01    1
# 16                                     0.0          93300.0 2015-01-01    1
# 17                                     0.0           5400.0 2015-01-01    1
# 18                                     0.0         131500.0 2015-01-01    1
# 19                                     1.0           5100.0 2015-01-01    1
# 20                                     2.0           2600.0 2015-01-01    1
# 21                                    37.0          21800.0 2015-01-01    1
# 22                                     2.0           1800.0 2015-01-01    1
